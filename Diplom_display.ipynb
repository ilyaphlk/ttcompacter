# %%
# !git clone -b ttlayernorm https://github.com/ilyaphlk/tt-layers.git
# Out:
# Cloning into 'tt-layers'...
# remote: Enumerating objects: 241, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 241 (delta 2), reused 6 (delta 2), pack-reused 233
# Receiving objects: 100% (241/241), 42.19 KiB | 8.44 MiB/s, done.
# Resolving deltas: 100% (164/164), done.

# %%
# !pip install ./tt-layers/
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing ./tt-layers
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#   Created wheel for t3nsor: filename=t3nsor-1.0-py3-none-any.whl size=16013 sha256=4e24f58d5e36f7cc9fdeb755301eed8019fea496d4449c6fdf76c72198259982
#   Stored in directory: /root/.cache/pip/wheels/c2/5d/16/d362ecccc7b3c6b2ed4d5bf1f1d5afec068baf42699d23cc45
# Successfully built t3nsor
# ...

# %%
# %cd /content/tt-layers/
# !git pull
# %cd ..
# !pip install ./tt-layers/ --upgrade --no-deps --force-reinstall

# %%
# !pip install fsspec -q
# !pip install wandb -q
# Out:
#      |████████████████████████████████| 140 kB 38.5 MB/s
#      |████████████████████████████████| 1.8 MB 27.0 MB/s
#      |████████████████████████████████| 181 kB 61.4 MB/s
#      |████████████████████████████████| 145 kB 67.9 MB/s
#      |████████████████████████████████| 63 kB 1.5 MB/s
# ...

# %%
# !pip install ttpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 317 kB 31.9 MB/s
# ...
#   Created wheel for ttpy: filename=ttpy-1.2.1-cp37-cp37m-linux_x86_64.whl size=2965095 sha256=f406557c4d84542178b71a5e542f9f01426026e19d9ed6987f87eedbd7f8b315
#   Stored in directory: /root/.cache/pip/wheels/1c/45/02/9593e1923b244554f33e29be39b1413772acac8c8a1ba30596
# Successfully built ttpy
# ...

# %%
# %env WANDB_API_KEY=#your wandb key here

# %%
# !wandb login  --relogin
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !git clone -b layer-norms https://github.com/ilyaphlk/ttcompacter.git
# Out:
# Cloning into 'ttcompacter'...
# remote: Enumerating objects: 2057, done.
# remote: Counting objects: 100% (407/407), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 2057 (delta 336), reused 351 (delta 304), pack-reused 1650
# Receiving objects: 100% (2057/2057), 268.49 KiB | 1.17 MiB/s, done.
# Resolving deltas: 100% (1287/1287), done.

# %%
#!pip install torch==1.8.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# !pip install ./ttcompacter/
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing ./ttcompacter
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#      |████████████████████████████████| 221 kB 31.5 MB/s
# ...
#      |████████████████████████████████| 22.3 MB 1.6 MB/s
# ...
#      |████████████████████████████████| 6.0 MB 45.8 MB/s
# ...
#      |████████████████████████████████| 10.3 MB 41.1 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 60.6 MB/s
# ...
#      |████████████████████████████████| 212 kB 68.1 MB/s
# ...
#      |████████████████████████████████| 69 kB 7.6 MB/s
# ...
#      |████████████████████████████████| 56 kB 824 kB/s
# ...

# %%
# %cd /content/ttcompacter/
# !git pull
# %cd ..
# !pip install ./ttcompacter/ --upgrade --force-reinstall --no-deps

# %%
# %cd ./ttcompacter/seq2seq
# Out:
# /content/ttcompacter/seq2seq

# %%
# !python3 run_seq2seq.py configs/debug_2.json
# Out:
# wandb: Currently logged in as: i_pakhalko. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.17
# wandb: Run data is saved locally in /content/ttcompacter/seq2seq/wandb/run-20220609_141541-12wxo3hd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run mrpc_debug_2
# wandb: ⭐️ View project at https://wandb.ai/i_pakhalko/tt_debug
# wandb: 🚀 View run at https://wandb.ai/i_pakhalko/tt_debug/runs/12wxo3hd
# https://huggingface.co/t5-base/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpldp7lmmk
# Downloading: 100% 1.20k/1.20k [00:00<00:00, 922kB/s]
# storing https://huggingface.co/t5-base/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/91e9fe874e06c44883b535d6c950b8b89d6eaa3298d8e7fb3b2c78039e9f8b7b.66b9637a52aa11e9285cdd6e668cc0df14b3bcf0b6674cf3ba5353c542649637
# ...
